# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn import tree
iris = load_iris()
X = iris.data
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
clf = DecisionTreeClassifier(criterion="entropy",min_impurity_decrease=0.002,random_state=0,min_samples_leaf=5)
clf.fit(X_train, y_train)
tree.plot_tree(clf)
# Out:
# [Text(0.375, 0.875, 'x[3] <= 0.8\nentropy = 1.581\nsamples = 112\nvalue = [37, 34, 41]'),
#  Text(0.25, 0.625, 'entropy = 0.0\nsamples = 37\nvalue = [37, 0, 0]'),
#  Text(0.5, 0.625, 'x[2] <= 4.95\nentropy = 0.994\nsamples = 75\nvalue = [0, 34, 41]'),
#  Text(0.25, 0.375, 'x[3] <= 1.55\nentropy = 0.414\nsamples = 36\nvalue = [0, 33, 3]'),
#  Text(0.125, 0.125, 'entropy = 0.0\nsamples = 30\nvalue = [0, 30, 0]'),
#  Text(0.375, 0.125, 'entropy = 1.0\nsamples = 6\nvalue = [0, 3, 3]'),
#  Text(0.75, 0.375, 'x[3] <= 1.85\nentropy = 0.172\nsamples = 39\nvalue = [0, 1, 38]'),
#  Text(0.625, 0.125, 'entropy = 0.503\nsamples = 9\nvalue = [0, 1, 8]'),
#  Text(0.875, 0.125, 'entropy = 0.0\nsamples = 30\nvalue = [0, 0, 30]')]

# %%
import numpy as np
import matplotlib.pyplot as plt

n_classes = 3
plot_colors = "ryb"

x_feature = 1
y_feature = 2

X = X_test[:, [x_feature, y_feature]]
y = y_test
y_predict = clf.predict(X_test)

for i, color in zip(range(n_classes), plot_colors):
            idx = np.where(y == i)
            plt.scatter(
                X[idx, 0],
                X[idx, 1],
                c=color,
                label=iris.target_names[i],
                cmap=plt.cm.RdYlBu,
                edgecolor="black",
                s=15,
            )

plt.xlabel(iris.feature_names[x_feature])
plt.ylabel(iris.feature_names[y_feature])
plt.legend(loc="lower right", borderpad=0, handletextpad=0)
plt.show()

for i, color in zip(range(n_classes), plot_colors):
            idx = np.where(y_predict == i)
            plt.scatter(
                X[idx, 0],
                X[idx, 1],
                c=color,
                label=iris.target_names[i],
                cmap=plt.cm.RdYlBu,
                edgecolor="black",
                s=15,
            )

plt.xlabel(iris.feature_names[x_feature])
plt.ylabel(iris.feature_names[y_feature])
plt.legend(loc="lower right", borderpad=0, handletextpad=0)
plt.show()
# Out:
# <ipython-input-18-8e94062fb220>:16: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(
# <ipython-input-18-8e94062fb220>:33: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(

# %%
x_feature = 1
y_feature = 3

X = X_test[:, [x_feature, y_feature]]
y = y_test
y_predict = clf.predict(X_test)

for i, color in zip(range(n_classes), plot_colors):
            idx = np.where(y == i)
            plt.scatter(
                X[idx, 0],
                X[idx, 1],
                c=color,
                label=iris.target_names[i],
                cmap=plt.cm.RdYlBu,
                edgecolor="black",
                s=15,
            )

plt.xlabel(iris.feature_names[x_feature])
plt.ylabel(iris.feature_names[y_feature])
plt.legend(loc="lower right", borderpad=0, handletextpad=0)
plt.show()

for i, color in zip(range(n_classes), plot_colors):
            idx = np.where(y_predict == i)
            plt.scatter(
                X[idx, 0],
                X[idx, 1],
                c=color,
                label=iris.target_names[i],
                cmap=plt.cm.RdYlBu,
                edgecolor="black",
                s=15,
            )

plt.xlabel(iris.feature_names[x_feature])
plt.ylabel(iris.feature_names[y_feature])
plt.legend(loc="lower right", borderpad=0, handletextpad=0)
plt.show()
# Out:
# <ipython-input-19-c7126120b157>:10: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(
# <ipython-input-19-c7126120b157>:27: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(

# %%
x_feature = 1
y_feature = 3

X = X_test[:, [x_feature, y_feature]]
y = y_test
y_predict = clf.predict(X_test)

for i, color in zip(range(n_classes), plot_colors):
            idx = np.where(y == i)
            plt.scatter(
                X[idx, 0],
                X[idx, 1],
                c=color,
                label=iris.target_names[i],
                cmap=plt.cm.RdYlBu,
                edgecolor="black",
                s=15,
            )

plt.xlabel(iris.feature_names[x_feature])
plt.ylabel(iris.feature_names[y_feature])
plt.legend(loc="lower right", borderpad=0, handletextpad=0)
plt.show()

for i, color in zip(range(n_classes), plot_colors):
            idx = np.where(y_predict == i)
            plt.scatter(
                X[idx, 0],
                X[idx, 1],
                c=color,
                label=iris.target_names[i],
                cmap=plt.cm.RdYlBu,
                edgecolor="black",
                s=15,
            )

plt.xlabel(iris.feature_names[x_feature])
plt.ylabel(iris.feature_names[y_feature])
plt.legend(loc="lower right", borderpad=0, handletextpad=0)
plt.show()
# Out:
# <ipython-input-21-c7126120b157>:10: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(
# <ipython-input-21-c7126120b157>:27: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(

# %%
x_feature = 0
y_feature = 2

X = X_test[:, [x_feature, y_feature]]
y = y_test
y_predict = clf.predict(X_test)

for i, color in zip(range(n_classes), plot_colors):
            idx = np.where(y == i)
            plt.scatter(
                X[idx, 0],
                X[idx, 1],
                c=color,
                label=iris.target_names[i],
                cmap=plt.cm.RdYlBu,
                edgecolor="black",
                s=15,
            )

plt.xlabel(iris.feature_names[x_feature])
plt.ylabel(iris.feature_names[y_feature])
plt.legend(loc="lower right", borderpad=0, handletextpad=0)
plt.show()

for i, color in zip(range(n_classes), plot_colors):
            idx = np.where(y_predict == i)
            plt.scatter(
                X[idx, 0],
                X[idx, 1],
                c=color,
                label=iris.target_names[i],
                cmap=plt.cm.RdYlBu,
                edgecolor="black",
                s=15,
            )

plt.xlabel(iris.feature_names[x_feature])
plt.ylabel(iris.feature_names[y_feature])
plt.legend(loc="lower right", borderpad=0, handletextpad=0)
plt.show()
# Out:
# <ipython-input-22-4832126891ae>:10: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(
# <ipython-input-22-4832126891ae>:27: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(

# %% [markdown]
# ## Hypothyroid

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv('/content/drive/My Drive/Materias/Colab Notebooks/IAA/thyroid.csv')

# %%
print(df)
# Out:
#       age sex on thyroxine query on thyroxine on antithyroid medication sick  \
# 0      41   F            f                  f                         f    f
# 1      23   F            f                  f                         f    f
# 2      46   M            f                  f                         f    f
# 3      70   F            t                  f                         f    f
# 4      70   F            f                  f                         f    f
# ...   ...  ..          ...                ...                       ...  ...
# 2795   70   M            f                  f                         f    f
# 2796   73   M            f                  t                         f    f
# 2797   75   M            f                  f                         f    f
# 2798   60   F            f                  f                         f    f
# 2799   81   F            f                  f                         f    f
#
# ...

# %%
target = df["label"].values.tolist()
feature_names = list(df.columns.values)[:-1]
target_names= list(set(df["label"].values.tolist()))
df = df.drop(columns=["label"])
data = df.to_numpy()

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
enc = OrdinalEncoder()

data = enc.fit_transform(data)

data_train, data_test, target_train, target_test = train_test_split(data, target, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(criterion="entropy",min_impurity_decrease=0.002,random_state=0,min_samples_leaf=5)
clf.fit(data_train, target_train)
tree.plot_tree(clf)
# Out:
# [Text(0.6136363636363636, 0.9375, 'x[25] <= 150.5\nentropy = 0.217\nsamples = 2100\nvalue = [7, 6, 48, 2039]'),
#  Text(0.36363636363636365, 0.8125, 'x[19] <= 32.5\nentropy = 0.087\nsamples = 2020\nvalue = [7, 6, 5, 2002]'),
#  Text(0.18181818181818182, 0.6875, 'x[25] <= 135.5\nentropy = 0.023\nsamples = 1941\nvalue = [0, 1, 3, 1937]'),
#  Text(0.09090909090909091, 0.5625, 'x[6] <= 0.5\nentropy = 0.007\nsamples = 1888\nvalue = [0, 1, 0, 1887]'),
#  Text(0.045454545454545456, 0.4375, 'entropy = 0.0\nsamples = 1870\nvalue = [0, 0, 0, 1870]'),
#  Text(0.13636363636363635, 0.4375, 'entropy = 0.31\nsamples = 18\nvalue = [0, 1, 0, 17]'),
#  Text(0.2727272727272727, 0.5625, 'x[17] <= 4.5\nentropy = 0.314\nsamples = 53\nvalue = [0, 0, 3, 50]'),
#  Text(0.22727272727272727, 0.4375, 'x[23] <= 52.5\nentropy = 0.779\nsamples = 13\nvalue = [0, 0, 3, 10]'),
#  Text(0.18181818181818182, 0.3125, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8]'),
# ...

# %%
# Crear la figura con un tamaño más grande
plt.figure(figsize=(20, 10))  # Ajusta el tamaño de la figura según tus necesidades

# Plotear el árbol
tree.plot_tree(clf, filled=True, feature_names=feature_names, class_names=target_names, rounded=True)

# Mostrar el gráfico
plt.show()

# Guardar el gráfico como un archivo
plt.savefig('decision_tree.png', dpi=300)  # Puedes ajustar el DPI según sea necesario

# %%
from sklearn.metrics import accuracy_score

target_predicted = clf.predict(data_test)

accuracy = accuracy_score(target_test, target_predicted)

print("El valor de accuracy obtenido es: {}".format(accuracy))
# Out:
# El valor de accuracy obtenido es: 0.9885714285714285
